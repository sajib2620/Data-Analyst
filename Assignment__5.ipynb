# %%
import pandas as pd # pandas import

# %%
df=pd.read_csv('/content/supershops.csv - supershops.csv.csv')# raed csv file and print

# %%
df
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.isnull().sum()# find out to null value each colum
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
#import minmaxScaler
from sklearn.preprocessing import MinMaxScaler

# %%
m=MinMaxScaler(feature_range=(0,1))#feature_rangetuple (min, max), default=(0, 1)

# %%
ms=m.fit(df[['Administration']])#Fit to data, then transform it.
ms
# Out:
# MinMaxScaler()

# %%
df #print
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
df['Administration']=ms.fit_transform(df[['Administration']])# fit to data transform
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61        0.651744  471784.10    Dhaka  192261.83
# 1        162597.70        0.761972  443898.53      Ctg  191792.06
# 2        153441.51        0.379579  407934.54  Rangpur  191050.39
# 3        144372.41        0.512998  383199.62    Dhaka  182901.99
# 4        142107.34        0.305328  366168.42  Rangpur  166187.94

# %%
df['Marketing Spend']=ms.fit_transform(df[['Marketing Spend']])# fit to data transform
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.651744  471784.10    Dhaka  192261.83
# 1         0.983359        0.761972  443898.53      Ctg  191792.06
# 2         0.927985        0.379579  407934.54  Rangpur  191050.39
# 3         0.873136        0.512998  383199.62    Dhaka  182901.99
# 4         0.859438        0.305328  366168.42  Rangpur  166187.94

# %%
df['Transport']=ms.fit_transform(df[['Transport']])# fit to data transform
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.651744   1.000000    Dhaka  192261.83
# 1         0.983359        0.761972   0.940893      Ctg  191792.06
# 2         0.927985        0.379579   0.864664  Rangpur  191050.39
# 3         0.873136        0.512998   0.812235    Dhaka  182901.99
# 4         0.859438        0.305328   0.776136  Rangpur  166187.94

# %%
df['Profit']=ms.fit_transform(df[['Profit']])
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.651744   1.000000    Dhaka  1.000000
# 1         0.983359        0.761972   0.940893      Ctg  0.997355
# 2         0.927985        0.379579   0.864664  Rangpur  0.993178
# 3         0.873136        0.512998   0.812235    Dhaka  0.947292
# 4         0.859438        0.305328   0.776136  Rangpur  0.853171

# %%
from sklearn.preprocessing import StandardScaler #import StandardScaler
scaler= StandardScaler() # scaler name assign in StandarScaler function

# %%
df['Marketing Spend']=scaler.fit_transform(df[['Marketing Spend']]) # fit to data transform

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.651744   1.000000    Dhaka  1.000000
# 1         0.983359        0.761972   0.940893      Ctg  0.997355
# 2         0.927985        0.379579   0.864664  Rangpur  0.993178
# 3         0.873136        0.512998   0.812235    Dhaka  0.947292
# 4         0.859438        0.305328   0.776136  Rangpur  0.853171

# %%
df['Administration']=scaler.fit_transform(df[['Administration']])

# %%
df.head(9)
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.897913        0.560753   1.000000    Dhaka  1.000000
# 1         1.955860        1.082807   0.940893      Ctg  0.997355
# 2         1.754364       -0.728257   0.864664  Rangpur  0.993178
# 3         1.554784       -0.096365   0.812235    Dhaka  0.947292
# 4         1.504937       -1.079919   0.776136  Rangpur  0.853171
# 5         1.279800       -0.776239   0.769126    Dhaka  0.801382
# 6         1.340066        0.932147   0.270710      Ctg  0.796490
# 7         1.245057        0.871980   0.686493  Rangpur  0.794407
# 8         1.030369        0.986952   0.660500    Dhaka  0.774468

# %%
df['Transport']=scaler.fit_transform(df[['Transport']]) # fit to data transform
df.head(8)
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.560753   2.165287    Dhaka  1.000000
# 1         0.983359        1.082807   1.929843      Ctg  0.997355
# 2         0.927985       -0.728257   1.626191  Rangpur  0.993178
# 3         0.873136       -0.096365   1.417348    Dhaka  0.947292
# 4         0.859438       -1.079919   1.273550  Rangpur  0.853171
# 5         0.797566       -0.776239   1.245627    Dhaka  0.801382
# 6         0.814128        0.932147  -0.739753      Ctg  0.796490
# 7         0.788018        0.871980   0.916470  Rangpur  0.794407

# %%
df['Profit']=scaler.fit_transform(df[['Profit']])
df.head(5)
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.560753   2.165287    Dhaka  2.011203
# 1         0.983359        1.082807   1.929843      Ctg  1.999430
# 2         0.927985       -0.728257   1.626191  Rangpur  1.980842
# 3         0.873136       -0.096365   1.417348    Dhaka  1.776627
# 4         0.859438       -1.079919   1.273550  Rangpur  1.357740

# %%
from sklearn.preprocessing import RobustScaler #import RobustScaler
transformer= RobustScaler()

# %%
df['Transport']=transformer.fit_transform(df[['Transport']]) # fit to data transform
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.560753   1.552016    Dhaka  2.011203
# 1         0.983359        1.082807   1.383714      Ctg  1.999430
# 2         0.927985       -0.728257   1.166654  Rangpur  1.980842
# 3         0.873136       -0.096365   1.017368    Dhaka  1.776627
# 4         0.859438       -1.079919   0.914576  Rangpur  1.357740

# %%
df['Marketing Spend']=transformer.fit_transform(df[['Marketing Spend']])# fit to data transform
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.672530        0.560753   1.552016    Dhaka  2.011203
# 1         1.452113        1.082807   1.383714      Ctg  1.999430
# 2         1.303634       -0.728257   1.166654  Rangpur  1.980842
# 3         1.156567       -0.096365   1.017368    Dhaka  1.776627
# 4         1.119836       -1.079919   0.914576  Rangpur  1.357740

# %%
df['Administration']=transformer.fit_transform(df[['Administration']])# fit to data transform
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.672530        0.345355   1.552016    Dhaka  2.011203
# 1         1.452113        0.697565   1.383714      Ctg  1.999430
# 2         1.303634       -0.524290   1.166654  Rangpur  1.980842
# 3         1.156567       -0.097977   1.017368    Dhaka  1.776627
# 4         1.119836       -0.761543   0.914576  Rangpur  1.357740

# %%
df['Profit']=transformer.fit_transform(df[['Profit']])# fit to data transform
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.672530        0.345355   1.552016    Dhaka  1.698340
# 1         1.452113        0.697565   1.383714      Ctg  1.688874
# 2         1.303634       -0.524290   1.166654  Rangpur  1.673929
# 3         1.156567       -0.097977   1.017368    Dhaka  1.509736
# 4         1.119836       -0.761543   0.914576  Rangpur  1.172943
